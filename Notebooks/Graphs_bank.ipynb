# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

def import_dataset(file_path):
    # Read the Excel file using Pandas read_excel function
    data = pd.read_excel(file_path)

    return data

# %%
bank_results = pd.read_excel('/content/bank_results.xlsx')
bank_results['Balancing Technique'].fillna('Standard', inplace=True)

# %%
bank_results_LogisticRegression = bank_results[(bank_results['Model Name'] == 'LogisticRegression()') | (bank_results['Model Name'] == 'LogisticRegression(class_weight=\'balanced\', random_state=42)')]

# %%
bank_results_LogisticRegression.drop(columns=['Model Name'],inplace=True)
bank_results_LogisticRegression = bank_results_LogisticRegression.reset_index(drop=True)
# Out:
# <ipython-input-5-1a60b3439f43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_LogisticRegression.drop(columns=['Model Name'],inplace=True)

# %%
from tabulate import tabulate
print(tabulate(bank_results_LogisticRegression,headers='keys',tablefmt='pipe'))
# Out:
# |    | Balancing Technique                   |   Accuracy |   Precision |   Recall |   AUC_ROCcurve |
# |---:|:--------------------------------------|-----------:|------------:|---------:|---------------:|
# |  0 | Standard                              |   0.905691 |    0.643172 | 0.409825 |       0.690088 |
# |  1 | with feature selection                |   0.905691 |    0.643172 | 0.409825 |       0.690088 |
# |  2 | SMOTE(train_data)                     |   0.905691 |    0.643172 | 0.409825 |       0.690088 |
# |  3 | SMOTE(whole_data)                     |   0.876483 |    0.860759 | 0.897114 |       0.876564 |
# |  4 | ADASYN(train_data)                    |   0.852829 |    0.428882 | 0.831579 |       0.84359  |
# |  5 | ADASYN(whole_data)                    |   0.876483 |    0.860759 | 0.897114 |       0.876564 |
# |  6 | UnderSampling(train_data)             |   0.852344 |    0.430415 | 0.865965 |       0.858266 |
# ...

# %%
bank_results_LogisticRegression.head()
bank_results_LogisticRegression['Balancing Technique'].fillna('Standard', inplace=True)

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plotting
plt.plot(bank_results_LogisticRegression['Balancing Technique'], bank_results_LogisticRegression['Accuracy'], marker='o', label='Accuracy')
plt.plot(bank_results_LogisticRegression['Balancing Technique'], bank_results_LogisticRegression['Precision'], marker='o', label='Precision')
plt.plot(bank_results_LogisticRegression['Balancing Technique'], bank_results_LogisticRegression['Recall'], marker='o', label='Recall')
plt.plot(bank_results_LogisticRegression['Balancing Technique'], bank_results_LogisticRegression['AUC_ROCcurve'], marker='o', label='AUC_ROCcurve')


# Customizing the plot
plt.xlabel('Balancing Technique')
plt.ylabel('Values')
plt.title('LogisticRegression')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.grid(True)  # Add grid lines
plt.legend()

# Show plot
plt.show()

# %%
bank_results_classificationalgo = bank_results[(bank_results['Model Name'] == 'SVC()') | (bank_results['Model Name'] == 'SVC(class_weight=\'balanced\', random_state=42)')]

bank_results_classificationalgo.drop(columns=['Model Name'],inplace=True)
bank_results_classificationalgo = bank_results_classificationalgo.reset_index(drop=True)
bank_results_classificationalgo['Balancing Technique'].fillna('Standard', inplace=True)
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plotting
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Accuracy'], marker='o', label='Accuracy')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Precision'], marker='o', label='Precision')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Recall'], marker='o', label='Recall')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['AUC_ROCcurve'], marker='o', label='AUC_ROCcurve')


# Customizing the plot
plt.xlabel('Balancing Technique')
plt.ylabel('Values')
plt.title('Support Vector Machines')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.grid(True)  # Add grid lines
plt.legend()

# Show plot
plt.show()
# Out:
# <ipython-input-9-c8791210c5b8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_classificationalgo.drop(columns=['Model Name'],inplace=True)

# %%
bank_results_classificationalgo = bank_results[(bank_results['Model Name'] == 'DecisionTreeClassifier()') | (bank_results['Model Name'] == 'DecisionTreeClassifier(class_weight=\'balanced\', random_state=42)')]

bank_results_classificationalgo.drop(columns=['Model Name'], inplace=True)
bank_results_classificationalgo = bank_results_classificationalgo.reset_index(drop=True)
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plotting
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Accuracy'], marker='o', label='Accuracy')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Precision'], marker='o', label='Precision')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Recall'], marker='o', label='Recall')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['AUC_ROCcurve'], marker='o', label='AUC_ROCcurve')

# Customizing the plot
plt.xlabel('Balancing Technique')
plt.ylabel('Values')
plt.title('DecisionTreeClassifier')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.grid(True)  # Add grid lines
plt.legend()

# Show plot
plt.show()
# Out:
# <ipython-input-10-4b7f79040f47>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_classificationalgo.drop(columns=['Model Name'], inplace=True)

# %%
bank_results_classificationalgo = bank_results[(bank_results['Model Name'] == 'RandomForestClassifier()') | (bank_results['Model Name'] == 'RandomForestClassifier(class_weight=\'balanced\', random_state=42)')]

bank_results_classificationalgo.drop(columns=['Model Name'], inplace=True)
bank_results_classificationalgo = bank_results_classificationalgo.reset_index(drop=True)
bank_results_classificationalgo['Balancing Technique'].fillna('Standard', inplace=True)
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plotting
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Accuracy'], marker='o', label='Accuracy')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Precision'], marker='o', label='Precision')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Recall'], marker='o', label='Recall')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['AUC_ROCcurve'], marker='o', label='AUC_ROCcurve')

# Customizing the plot
plt.xlabel('Balancing Technique')
plt.ylabel('Values')
plt.title('RandomForestClassifier')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.grid(True)  # Add grid lines
plt.legend()

# Show plot
plt.show()
# Out:
# <ipython-input-11-2db3d7647070>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_classificationalgo.drop(columns=['Model Name'], inplace=True)

# %%
bank_results_classificationalgo = bank_results[bank_results['Model Name'] == 'BernoulliNB()']

bank_results_classificationalgo.drop(columns=['Model Name'], inplace=True)
bank_results_classificationalgo = bank_results_classificationalgo.reset_index(drop=True)
bank_results_classificationalgo['Balancing Technique'].fillna('Standard', inplace=True)
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plotting
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Accuracy'], marker='o', label='Accuracy')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Precision'], marker='o', label='Precision')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['Recall'], marker='o', label='Recall')
plt.plot(bank_results_classificationalgo['Balancing Technique'], bank_results_classificationalgo['AUC_ROCcurve'], marker='o', label='AUC_ROCcurve')

# Customizing the plot
plt.xlabel('Balancing Technique')
plt.ylabel('Values')
plt.title('BernoulliNB')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.grid(True)  # Add grid lines
plt.legend()

# Show plot
plt.show()
# Out:
# <ipython-input-12-e1c2d3f2e6ce>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_classificationalgo.drop(columns=['Model Name'], inplace=True)

# %%
bank_results_balancingtechnique = bank_results[(bank_results['Balancing Technique'] == 'Standard') | (bank_results['Balancing Technique'] == 'with feature selection') | (bank_results['Balancing Technique'] == 'SMOTE(train_data)') | (bank_results['Balancing Technique'] == 'SMOTE(whole_data)')]
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('SVC(class_weight=\'balanced\', random_state=42)', 'SVC()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('DecisionTreeClassifier(class_weight=\'balanced\', random_state=42)', 'DecisionTreeClassifier()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('RandomForestClassifier(class_weight=\'balanced\', random_state=42)', 'RandomForestClassifier()')
# Out:
# <ipython-input-13-e1ce8aa91768>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
# <ipython-input-13-e1ce8aa91768>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
balancing_techniques = bank_results_balancingtechnique['Balancing Technique'].unique()
metrics = bank_results_balancingtechnique[['Accuracy', 'Precision', 'Recall', 'AUC_ROCcurve']]

# Define marker styles for each balancing technique
marker_styles = ['o', 's', 'x', 'D']

# Define colors for each balancing technique
color_map = {
    'Standard': 'blue',
    'with feature selection': 'green',
    'SMOTE(train_data)': 'red',
    'SMOTE(whole_data)': 'orange'
}

# Plotting
plt.figure(figsize=(10, 6))

for balancing_technique, marker in zip(balancing_techniques, marker_styles):
    for metric in metrics.columns:
        color = color_map[balancing_technique]
        if metric == 'Accuracy':  # Use square marker for Accuracy
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='o', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Precision':  # Use triangle marker for Precision
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='s', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Recall':  # Use '*' marker for Recall
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='x', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'AUC_ROCcurve':  # Use circle with thick boundary for AUC_ROCcurve
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='+', markersize=12, markerfacecolor='none', markeredgewidth=2, label=f'{metric} - {balancing_technique}', color=color)

# Customizing the plot
plt.xlabel('Model Name')
plt.ylabel('Values')
plt.title('SMOTE')
plt.xticks(rotation=70)
plt.grid(True)
plt.legend(title='Metric - Balancing Technique', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# %%
bank_results_balancingtechnique = bank_results[(bank_results['Balancing Technique'] == 'Standard') | (bank_results['Balancing Technique'] == 'with feature selection') | (bank_results['Balancing Technique'] == 'ADASYN(train_data)') | (bank_results['Balancing Technique'] == 'ADASYN(whole_data)')]
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('SVC(class_weight=\'balanced\', random_state=42)', 'SVC()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('DecisionTreeClassifier(class_weight=\'balanced\', random_state=42)', 'DecisionTreeClassifier()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('RandomForestClassifier(class_weight=\'balanced\', random_state=42)', 'RandomForestClassifier()')
# Out:
# <ipython-input-15-95fcc8799010>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
# <ipython-input-15-95fcc8799010>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
balancing_techniques = bank_results_balancingtechnique['Balancing Technique'].unique()
metrics = bank_results_balancingtechnique[['Accuracy', 'Precision', 'Recall', 'AUC_ROCcurve']]

# Define marker styles for each balancing technique
marker_styles = ['o', 's', 'x', 'D']

# Define colors for each balancing technique
color_map = {
    'Standard': 'blue',
    'with feature selection': 'green',
    'ADASYN(train_data)': 'red',
    'ADASYN(whole_data)': 'orange'
}

# Plotting
plt.figure(figsize=(10, 6))

for balancing_technique, marker in zip(balancing_techniques, marker_styles):
    for metric in metrics.columns:
        color = color_map[balancing_technique]
        if metric == 'Accuracy':  # Use square marker for Accuracy
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='o', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Precision':  # Use triangle marker for Precision
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='s', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Recall':  # Use '*' marker for Recall
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='x', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'AUC_ROCcurve':  # Use circle with thick boundary for AUC_ROCcurve
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='+', markersize=12, markerfacecolor='none', markeredgewidth=2, label=f'{metric} - {balancing_technique}', color=color)

# Customizing the plot
plt.xlabel('Model Name')
plt.ylabel('Values')
plt.title('ADASYN')
plt.xticks(rotation=70)
plt.grid(True)
plt.legend(title='Metric - Balancing Technique', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# %%
bank_results_balancingtechnique = bank_results[(bank_results['Balancing Technique'] == 'Standard') | (bank_results['Balancing Technique'] == 'with feature selection') | (bank_results['Balancing Technique'] == 'UnderSampling(train_data)') | (bank_results['Balancing Technique'] == 'ADASYN(whole_data)')]
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('SVC(class_weight=\'balanced\', random_state=42)', 'SVC()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('DecisionTreeClassifier(class_weight=\'balanced\', random_state=42)', 'DecisionTreeClassifier()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('RandomForestClassifier(class_weight=\'balanced\', random_state=42)', 'RandomForestClassifier()')
# Out:
# <ipython-input-17-e1ecc501dbfd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
# <ipython-input-17-e1ecc501dbfd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
balancing_techniques = bank_results_balancingtechnique['Balancing Technique'].unique()
metrics = bank_results_balancingtechnique[['Accuracy', 'Precision', 'Recall', 'AUC_ROCcurve']]

# Define marker styles for each balancing technique
marker_styles = ['o', 's', 'x', 'D']

# Define colors for each balancing technique
color_map = {
    'Standard': 'blue',
    'with feature selection': 'green',
    'UnderSampling(train_data)': 'red',
    'UnderSampling(whole_data)': 'orange',
    'ADASYN(whole_data)': 'purple'  # Adding ADASYN(whole_data) to color_map
}

# Plotting
plt.figure(figsize=(10, 6))

for balancing_technique, marker in zip(balancing_techniques, marker_styles):
    for metric in metrics.columns:
        color = color_map.get(balancing_technique, 'black')  # Use black color if not found in color_map
        if metric == 'Accuracy':  # Use square marker for Accuracy
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='o', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Precision':  # Use triangle marker for Precision
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='s', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Recall':  # Use '*' marker for Recall
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='x', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'AUC_ROCcurve':  # Use circle with thick boundary for AUC_ROCcurve
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='+', markersize=12, markerfacecolor='none', markeredgewidth=2, label=f'{metric} - {balancing_technique}', color=color)

# Customizing the plot
plt.xlabel('Model Name')
plt.ylabel('Values')
plt.title('UnderSampling')
plt.xticks(rotation=70)
plt.grid(True)
plt.legend(title='Metric - Balancing Technique', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# %%
bank_results_balancingtechnique = bank_results[(bank_results['Balancing Technique'] == 'Standard') | (bank_results['Balancing Technique']== 'with feature selection')| (bank_results['Balancing Technique']== 'Class weightining(Algorithmic Method)')]
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('SVC(class_weight=\'balanced\', random_state=42)', 'SVC()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('DecisionTreeClassifier(class_weight=\'balanced\', random_state=42)', 'DecisionTreeClassifier()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('RandomForestClassifier(class_weight=\'balanced\', random_state=42)', 'RandomForestClassifier()')
# Out:
# <ipython-input-19-7e0d0cd51348>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
# <ipython-input-19-7e0d0cd51348>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
balancing_techniques = bank_results_balancingtechnique['Balancing Technique'].unique()
metrics = bank_results_balancingtechnique[['Accuracy', 'Precision', 'Recall', 'AUC_ROCcurve']]

# Define marker styles for each balancing technique
marker_styles = ['o', 's', 'x', 'D']

# Define colors for each balancing technique
color_map = {
    'Standard': 'blue',
    'with feature selection': 'green',
    'Class weightining(Algorithmic Method)': 'red'
}

# Plotting
plt.figure(figsize=(10, 6))

for balancing_technique, marker in zip(balancing_techniques, marker_styles):
    for metric in metrics.columns:
        color = color_map[balancing_technique]
        if metric == 'Accuracy':  # Use square marker for Accuracy
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='o', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Precision':  # Use triangle marker for Precision
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='s', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Recall':  # Use '*' marker for Recall
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='x', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'AUC_ROCcurve':  # Use circle with thick boundary for AUC_ROCcurve
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='+', markersize=12, markerfacecolor='none', markeredgewidth=2, label=f'{metric} - {balancing_technique}', color=color)

# Customizing the plot
plt.xlabel('Model Name')
plt.ylabel('Values')
plt.title('Class weightining(Algorithmic Method)')
plt.xticks(rotation=70)
plt.grid(True)
plt.legend(title='Metric - Balancing Technique', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# %%
bank_results_balancingtechnique = bank_results[(bank_results['Balancing Technique'] == 'Standard') | (bank_results['Balancing Technique']== 'with feature selection')| (bank_results['Balancing Technique']== 'GAN(whole_data)')|(bank_results['Balancing Technique']== 'GAN(train_data)')]
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('SVC(class_weight=\'balanced\', random_state=42)', 'SVC()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('DecisionTreeClassifier(class_weight=\'balanced\', random_state=42)', 'DecisionTreeClassifier()')
bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('RandomForestClassifier(class_weight=\'balanced\', random_state=42)', 'RandomForestClassifier()')
# Out:
# <ipython-input-21-0b74429fa770>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_results_balancingtechnique['Model Name'] = bank_results_balancingtechnique['Model Name'].replace('LogisticRegression(class_weight=\'balanced\', random_state=42)', 'LogisticRegression()')
# <ipython-input-21-0b74429fa770>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
balancing_techniques = bank_results_balancingtechnique['Balancing Technique'].unique()
metrics = bank_results_balancingtechnique[['Accuracy', 'Precision', 'Recall', 'AUC_ROCcurve']]

# Define marker styles for each balancing technique
marker_styles = ['o', 's', 'x', 'D']

# Define colors for each balancing technique
color_map = {
    'Standard': 'blue',
    'with feature selection': 'green',
    'GAN(whole_data)': 'red',
    'GAN(train_data)': 'orange'

}

# Plotting
plt.figure(figsize=(10, 6))

for balancing_technique, marker in zip(balancing_techniques, marker_styles):
    for metric in metrics.columns:
        color = color_map[balancing_technique]
        if metric == 'Accuracy':  # Use square marker for Accuracy
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='o', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Precision':  # Use triangle marker for Precision
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='s', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'Recall':  # Use '*' marker for Recall
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='x', markersize=8, label=f'{metric} - {balancing_technique}', color=color)
        elif metric == 'AUC_ROCcurve':  # Use circle with thick boundary for AUC_ROCcurve
            plt.plot(bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique]['Model Name'], bank_results_balancingtechnique[bank_results_balancingtechnique['Balancing Technique'] == balancing_technique][metric], marker='+', markersize=12, markerfacecolor='none', markeredgewidth=2, label=f'{metric} - {balancing_technique}', color=color)

# Customizing the plot
plt.xlabel('Model Name')
plt.ylabel('Values')
plt.title('GAN(Deep Learning Algo)')
plt.xticks(rotation=70)
plt.grid(True)
plt.legend(title='Metric - Balancing Technique', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()
